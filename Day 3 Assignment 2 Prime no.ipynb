# %%
for num in range(1, 201):
    num= input("Enter any Number- ")
    num= int(num)
    if (num > 1):
        for i in range(2,201):
            if(num%i==0):
                print(num, "is not a prime")
            else:
                print(num, "is prime")
                print(num)
    else:
        print(num)
# Out:
# Enter any Number- 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is not a prime
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# 7 is prime
# 7
# ...
